# %%
import yfinance as yf
# Out:
# /Users/niloy/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
search_result = yf.Search("bandhan small cap fund")

# %%
search_result.response
# Out:
# {'explains': [],
#  'count': 5,
#  'quotes': [],
#  'news': [],
#  'nav': [],
#  'lists': [{'slug': 'most-bought-by-activist-hedge-funds',
#    'name': 'Most Bought By Activist Hedge Funds',
#    'index': 'most-bought-by-activist-hedge-funds',
#    'score': 20.948578,
#    'type': 'ALGO_WATCHLIST',
#    'brandSlug': 'yahoo-finance',
#    'pfId': 'most_bought_by_activist_hedge_funds',
#    'symbolCount': 13,
#    'dailyPercentGain': -0.8945699408839995,
#    'followerCount': 59732,
#    'iconUrl': 'https://edgecast-img.yahoo.net/mysterio/api/110f1012357c7b3e87d14912e7023f819b61278e7f0e90a3825821d2ef3c427c/finance/resizefill_w96_h96/https://s.yimg.com/uc/fin/img/most-bought-activist.png',
#    'userId': '5SSSFLJVWAMDKUGZM5HLSSBNAY'},
#   {'slug': 'most-active-small-cap-stocks',
#    'name': 'Most Active Small-Cap Stocks',
#    'index': 'most-active-small-cap-stocks',
#    'score': 17.720083,
#    'type': 'ALGO_WATCHLIST',
#    'brandSlug': 'yahoo-finance',
# ...

# %%
ticker = yf.Ticker("0P0001J6FU.BO")

# %%
history = ticker.history(period="5y")
info = ticker.info

# %%
history.head()
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2021-06-30 00:00:00+05:30  20.520000  20.520000  20.520000  20.520000       0
# 2021-07-01 00:00:00+05:30  20.709999  20.709999  20.709999  20.709999       0
# 2021-07-02 00:00:00+05:30  20.799999  20.799999  20.799999  20.799999       0
# 2021-07-05 00:00:00+05:30  20.990000  20.990000  20.990000  20.990000       0
# 2021-07-06 00:00:00+05:30  20.840000  20.840000  20.840000  20.840000       0
#
#                            Dividends  Stock Splits  Capital Gains
# Date
# 2021-06-30 00:00:00+05:30        0.0           0.0            0.0
# 2021-07-01 00:00:00+05:30        0.0           0.0            0.0
# 2021-07-02 00:00:00+05:30        0.0           0.0            0.0
# 2021-07-05 00:00:00+05:30        0.0           0.0            0.0
# 2021-07-06 00:00:00+05:30        0.0           0.0            0.0

# %%
info
# Out:
# {'address1': 'Jupiter Mill, Senapati Bapat Marg, Elphinstone Road (West), Mumbai',
#  'address2': '6th Floor, 841, One World Center',
#  'address3': 'Bandhan Asset Management Company Limited',
#  'phone': '022-66289999',
#  'companyOfficers': [],
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 54.567,
#  'regularMarketPreviousClose': 54.567,
#  'trailingPE': 17.549164,
#  'yield': 0.0,
#  'ytdReturn': 3.8934,
#  'fiftyTwoWeekLow': 44.631,
#  'fiftyTwoWeekHigh': 54.861,
#  'fiftyDayAverage': 52.90572,
#  'twoHundredDayAverage': 50.849766,
#  'currency': 'INR',
#  'tradeable': False,
#  'morningStarOverallRating': 5,
#  'morningStarRiskRating': 4,
#  'annualReportExpenseRatio': 0.0,
#  'beta3Year': 0.91,
#  'fundInceptionDate': 1582675200,
#  'annualHoldingsTurnover': 0.5196,
#  'quoteType': 'MUTUALFUND',
#  'symbol': '0P0001J6FU.BO',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Fund',
#  'quoteSourceName': 'Delayed Quote',
# ...
